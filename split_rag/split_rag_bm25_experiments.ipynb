# %% [markdown]
# # Split-RAG experiments
# This notebook implements the Split-RAG architecture, a specialized retrieval strategy designed to overcome the limitations identified during the baseline experiments. While the baseline Naive RAG treated legislation and jurisprudence as a single unstructured corpus, Split-RAG introduces a functional decoupling of these data sources.
#
# **Baseline RAGAs results**:
# * faithfulness: 0.7205
# * factual correctness: 0.3340
# * context precision: 0.8750
# * context recall: 0.3417

# %% [markdown]
# ## Imports

# %%
import os
import time
import pandas as pd
import json
from datasets import Dataset
from dotenv import load_dotenv

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_openai import AzureOpenAIEmbeddings
from langchain_chroma import Chroma
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from openai import AsyncAzureOpenAI
from langchain_openai import AzureChatOpenAI
from langchain_classic.retrievers import ParentDocumentRetriever
from langchain_classic.retrievers import EnsembleRetriever
from langchain_classic.retrievers import BM25Retriever
from langchain_classic.retrievers import ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import LLMChainFilter
from langchain_classic.storage import LocalFileStore, create_kv_docstore



from ragas.metrics import Faithfulness, FactualCorrectness, ContextPrecision, ContextRecall
from ragas.llms import llm_factory
import nest_asyncio
from ragas import aevaluate 
from ragas import RunConfig
# Out:
# C:\Users\verkad004\AppData\Local\Temp\ipykernel_26524\1568699709.py:24: DeprecationWarning: Importing Faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import Faithfulness
#   from ragas.metrics import Faithfulness, FactualCorrectness, ContextPrecision, ContextRecall
# C:\Users\verkad004\AppData\Local\Temp\ipykernel_26524\1568699709.py:24: DeprecationWarning: Importing FactualCorrectness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import FactualCorrectness
#   from ragas.metrics import Faithfulness, FactualCorrectness, ContextPrecision, ContextRecall
# C:\Users\verkad004\AppData\Local\Temp\ipykernel_26524\1568699709.py:24: DeprecationWarning: Importing ContextPrecision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import ContextPrecision
#   from ragas.metrics import Faithfulness, FactualCorrectness, ContextPrecision, ContextRecall
# C:\Users\verkad004\AppData\Local\Temp\ipykernel_26524\1568699709.py:24: DeprecationWarning: Importing ContextRecall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import ContextRecall
#   from ragas.metrics import Faithfulness, FactualCorrectness, ContextPrecision, ContextRecall

# %% [markdown]
# ## Environment variables

# %%
env_path = os.path.join("..", ".env")
load_dotenv(dotenv_path=env_path)

endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
api_version = os.getenv("AZURE_OPENAI_API_VERSION")
embedding_deployment = os.getenv("AZURE_EMBEDDING_DEPLOYMENT")
deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT")

# Initialize Azure AD token provider
token_provider = get_bearer_token_provider(
    DefaultAzureCredential(),
    "https://cognitiveservices.azure.com/.default"
)

# %% [markdown]
# ## Data Loading
# In contrast to the baseline experiments, the Split-RAG architecture employs a decoupled data strategy. Rather than treating legislation and jurisprudence as a unified corpus, this approach maintains them as two distinct, specialized knowledge bases.

# %%
legislation_path = '../data/legislation_omgevingswet_cleaned.jsonl'
jurisprudence_path = '../data/jurisprudence_omgevingswet_cleaned.jsonl'

common_cols = ['id', 'title', 'text', 'word_count', 'source_type']
df_legislation = pd.read_json(legislation_path, lines=True)
df_jurisprudence = pd.read_json(jurisprudence_path, lines=True)

df_leg_sub = df_legislation[common_cols]
df_jur_sub = df_jurisprudence[common_cols]

print(f"Legislation loaded: {len(df_legislation)} rows")
print(f"Jurisprudence loaded: {len(df_jurisprudence)} rows")
# Out:
# Legislation loaded: 725 rows
# Jurisprudence loaded: 3404 rows

# %%
# Legislation document creation
docs_legislation = [
    Document(
        page_content=str(row['text']),
        metadata={
            "id": row['id'],
            "title": row['title'],
            "source_type": row['source_type'],
            "word_count": row['word_count']
        }
    ) for _, row in df_leg_sub.iterrows()
]

# jurisprudence document creation
docs_jurisprudence = [
    Document(
        page_content=str(row['text']),
        metadata={
            "id": row['id'],
            "title": row['title'],
            "source_type": row['source_type'],
            "word_count": row['word_count']
        }
    ) for _, row in df_jur_sub.iterrows()
]

print(f"Created {len(docs_legislation)} legislation documents.")
print(f"Created {len(docs_jurisprudence)} jurisprudence documents.")
# Out:
# Created 725 legislation documents.
# Created 3404 jurisprudence documents.

# %% [markdown]
# # Retrieving documents per dataset

# %%
embeddings = AzureOpenAIEmbeddings(
    azure_deployment=embedding_deployment, 
    azure_endpoint=endpoint,              
    openai_api_version=api_version,       
    azure_ad_token_provider=token_provider
)

# %% [markdown]
# ## Legislation
# For legislation, we are implementing a **Parent Document Retrieval (PDR)** system. Instead of standard chunking, this system employs a hierarchical approach.
#
# **Rationale:**
# Laws are inherently hierarchical and logically structured. Recent research (Lim et al., 2025; Guo et al., 2025) demonstrates that multi-granular context is superior to fixed chunk sizes. By indexing small child chunks (400 tokens), we maximise search precision. However, to prevent the AI from losing the legal context, the full parent” article is served to the model as context upon a match. This chunk-to-context reconstruction directly addresses the shortcomings of naive RAG systems when dealing with complex legislation (Lim et al., 2025).

# %%
# Splitter for search chunks (childs)
child_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400, 
    chunk_overlap=50
)

# Define paths
vdb_base_path = "../data/vector_stores"
leg_child_path = os.path.join(vdb_base_path, "split_legislation_child")
leg_parent_path = os.path.join(vdb_base_path, "split_legislation_parent_store")

# Parent storage for disk
fs = LocalFileStore(leg_parent_path)
parent_docstore = create_kv_docstore(fs) 

# Child database
vdb_leg_child = Chroma(
    collection_name="leg_pdr_final",
    embedding_function=embeddings, 
    persist_directory=leg_child_path
)

# Retriever that links child chunks (cosine similarity)
retriever_leg_parent = ParentDocumentRetriever(
    vectorstore=vdb_leg_child,
    docstore=parent_docstore,
    child_splitter=child_splitter,
)

# %%
# Check if disk is empty and populate using unique, stable IDs
if vdb_leg_child._collection.count() == 0:
    print("Vectordatabase empty. Indexing legislation documents...")
    batch_size = 50
    
    for i in range(0, len(docs_legislation), batch_size):
        batch = docs_legislation[i : i + batch_size]
        
        # Extract fixed unique IDs from document metadata
        batch_ids = [str(doc.metadata["id"]) for doc in batch]
        
        # Populate parent docstore and child vector store simultaneously
        retriever_leg_parent.add_documents(batch, ids=batch_ids)
        
        print(f"Progress: {min(i + batch_size, len(docs_legislation))}/{len(docs_legislation)} articles done")
        time.sleep(1)
        
    # Force persistence to disk
    if hasattr(vdb_leg_child, 'persist'):
        vdb_leg_child.persist()
        
    print(f"Database is ready. Total chunks: {vdb_leg_child._collection.count()}")
else:
    print(f"Database is ready. Loaded {vdb_leg_child._collection.count()} chunks from disk.")
# Out:
# Database is ready. Loaded 4100 chunks from disk.

# %% [markdown]
# ## Jurisprudence
# For the jurisprudence, we use Structure-Aware Chunking.
#
# **Rationale:**
# Jurisprudence is narrative and story-driven in nature, meaning that relevant information is often scattered across lengthy texts. In line with the findings in *LegalBench-RAG* (Pipitone & Alami, 2024), standard retrieval is often insufficient for this type of document. We use a splitter that preserves the logical integrity of the judgment (splitting by ECLI and paragraphs).

# %%
structure_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    separators=[
        "\nECLI:",          # Prioriteit voor de start van een nieuwe uitspraak
        "\n\n",            # Paragrafen
        "\n",              # Regels
        ". ",              # Zinnen
        " "                # Woorden
    ]
)

# Pas de splitter toe op je jurisprudentie documenten
chunks_juris_structure = structure_splitter.split_documents(docs_jurisprudence)

print(f"Jurisprudence: Structure-Aware Results")
print(f"Totaal aantal chunks: {len(chunks_juris_structure)}")

# Check de eerste chunk
if chunks_juris_structure:
    print(f"\nSample Metadata: {chunks_juris_structure[0].metadata}")
    print(f"Sample Content: {chunks_juris_structure[0].page_content[:300]}...")
# Out:
# Jurisprudence: Structure-Aware Results
# Totaal aantal chunks: 51321
#
# Sample Metadata: {'id': 'ECLI:NL:RBGEL:2024:26', 'title': 'ECLI:NL:RBGEL:2024:26, Rechtbank Gelderland, 05-01-2024, AWB-22_5249 en 22_5252', 'source_type': 'jurisprudence', 'word_count': 2403}
# Sample Content: Weigering handhavingsverzoeken m.b.t. geitenhouderij. Intern salderen. Beroep gegrond vanwege een motiveringsgebrek. De rechtsgevolgen worden door de rechtbank in stand gelaten omdat in het verweerschrift afdoende is onderbouwd dat er geen sprake is van een overtreding van de Wnb.
#
#
#
#
# Zittingspl...

# %%
def create_vdb_in_batches(chunks, path, name, embeddings, batch_size=50):
    print(f"Checking existing progress for: {name}")
    
    # 1. Open of maak de database aan
    vector_db = Chroma(
        persist_directory=path,
        embedding_function=embeddings
    )
    
    # 2. Kijk wat er al in zit (op basis van metadata 'id' of 'source')
    # We halen de unieke bronnen op die al verwerkt zijn
    existing_count = vector_db._collection.count()
    
    if existing_count > 0:
        print(f"Hervatten: Er staan al {existing_count} chunks in de database.")
        # We skippen de chunks die al aanwezig zijn
        # Let op: dit werkt het best als de volgorde van 'chunks' altijd hetzelfde is
        remaining_chunks = chunks[existing_count:]
    else:
        print("Geen bestaande data gevonden. We starten vanaf het begin.")
        remaining_chunks = chunks

    if not remaining_chunks:
        print(f"Alle chunks voor {name} zijn al verwerkt!\n")
        return vector_db

    # 3. Voeg de resterende chunks toe in batches
    print(f"Nog {len(remaining_chunks)} chunks toe te voegen...")
    
    for i in range(0, len(remaining_chunks), batch_size):
        batch = remaining_chunks[i : i + batch_size]
        vector_db.add_documents(documents=batch)
        
        current_total = existing_count + i + len(batch)
        print(f"Progress for {name}: {current_total}/{len(chunks)} chunks totaal...")
        
        # Voorkom rate limits en geef de schijf tijd om te schrijven
        time.sleep(1) 
        
    print(f"{name} Vector Store succesvol bijgewerkt bij {path}\n")
    return vector_db

# Pad voor de jurisprudentie database
juris_vdb_path = os.path.join(vdb_base_path, "split_jurisprudence_structure")

# Gebruik je vertrouwde functie om de vdb aan te maken
vdb_juris_split = create_vdb_in_batches(
    chunks=chunks_juris_structure, 
    path=juris_vdb_path, 
    name="Jurisprudence-Structure",
    embeddings=embeddings,
    batch_size=50
)
# Out:
# Checking existing progress for: Jurisprudence-Structure
# Hervatten: Er staan al 51321 chunks in de database.
# Alle chunks voor Jurisprudence-Structure zijn al verwerkt!

# %%
# Load database
vdb_juris_split = Chroma(
    persist_directory=os.path.join(vdb_base_path, "split_jurisprudence_structure"),
    embedding_function=embeddings
)

print(f"Jurisprudence chunks geladen: {vdb_juris_split._collection.count()}")
# Out:
# Jurisprudence chunks geladen: 51321

# %%
retriever_juris_structure = vdb_juris_split.as_retriever(
    search_type="mmr", 
    search_kwargs={
        "k": 15,                # fetch 15 fragments
        "fetch_k": 50,          # fetch 50 and retrieve 15 most diverse
        "lambda_mult": 0.5      # balance between relevance and diversity
    }
)

# %% [markdown]
# ## Split-RAG

# %%
vdb_path = "../data/vector_stores"

vdb_leg_child = Chroma(
    persist_directory=os.path.join(vdb_path, "split_legislation_child"),
    embedding_function=embeddings
)

# Load parent store (complete articles)
fs_leg = LocalFileStore(os.path.join(vdb_path, "split_legislation_parent_store"))
parent_docstore = create_kv_docstore(fs_leg)

vdb_juris_split = Chroma(
    persist_directory=os.path.join(vdb_path, "split_jurisprudence_structure"),
    embedding_function=embeddings
)

# Check chunk counts for your Split-RAG architecture
print(f"Split-RAG Legislation chunks: {vdb_leg_child._collection.count()}")
print(f"Split-RAG Jurisprudence chunks: {vdb_juris_split._collection.count()}")
# Out:
# Split-RAG Legislation chunks: 2050
# Split-RAG Jurisprudence chunks: 51321

# %% [markdown]
# ## RAGAs evaluation

# %% [markdown]
# ### QA pairs

# %%
# Load JSON file
file_path = "../data/QA_pairs_evaluation.json" 

with open(file_path, 'r', encoding='utf-8') as f:
    qa_list = json.load(f)

# Convert to DataFrame
df_qa = pd.DataFrame(qa_list)
print(f"Dataset geladen: {len(df_qa)} vragen gevonden.")
# Out:
# Dataset geladen: 10 vragen gevonden.

# %% [markdown]
# ### RAGAs dataset generations

# %%
client = AsyncAzureOpenAI(
    azure_endpoint=endpoint,
    azure_deployment=deployment,
    api_version=api_version,
    azure_ad_token_provider=token_provider,
)

# %%
# retriever run 1 & 2
ensemble_retriever = EnsembleRetriever(
    retrievers=[retriever_leg_parent, retriever_juris_structure],
    weights=[0.6, 0.4] 
)

# %%
async def run_evaluation_loop(retriever, dataset_list, strategy_name): 
    questions = []
    all_contexts = []
    ground_truths = []
    all_answers = []

    system_prompt = (
    "Je bent een juridisch assistent voor de Gemeente Amsterdam.\n"
    "Beantwoord de vraag uitsluitend op basis van de verstrekte context.\n\n"
    "EISEN:\n"
    "1. Noem het specifieke wetsartikel uit de Omgevingswet.\n"
    "2. Noem het ECLI-nummer van de relevante uitspraak.\n"
    "3. Als informatie ontbreekt, geef dit dan expliciet aan."
)


    print(f"Start retrieval and generation for: {strategy_name}...")

    for item in dataset_list:
        q = item['question']
        gt = item['ground_truth']
        
        # Retrieval
        docs = retriever.invoke(q) 
        ctx_list = [doc.page_content for doc in docs]
        context_text = "\n\n".join(ctx_list)
        
        # Generation
        resp = await client.chat.completions.create(
            model=deployment,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": f"Context: {context_text}\n\nVraag: {q}"},
            ],
            temperature=0 
        )
        answer = resp.choices[0].message.content
        
        # Save to lists
        questions.append(q)
        all_contexts.append(ctx_list) 
        ground_truths.append(gt)
        all_answers.append(answer)

    # Dataset object for RAGAs
    ds = Dataset.from_dict({
        "question": questions,
        "answer": all_answers,
        "contexts": all_contexts,
        "ground_truth": ground_truths
    })
    
    os.makedirs("../data/results", exist_ok=True)
    ds.to_pandas().to_csv(f"../data/results/results_{strategy_name}.csv", index=False, encoding='utf-16')
    
    return ds
# Out:
# Start retrieval and generation for: split-rag...

# %% [markdown]
# ## Results and analysis

# %%
evaluator_llm = llm_factory(
    model=deployment,
    client=client,
    max_tokens=4096
    )

config = RunConfig(
    timeout=240,     
    max_retries=20, 
    max_wait=60,
    max_workers=1,
    seed=42,      
)

nest_asyncio.apply()

# Initialize metrics
metrics = [
    Faithfulness(llm=evaluator_llm),
    FactualCorrectness(llm=evaluator_llm), 
    ContextPrecision(llm=evaluator_llm),
    ContextRecall(llm=evaluator_llm)
]

# %% [markdown]
# # BM25 retriever + MMR
# The initial results of the Split-RAG model show high faithfulness (0.85), but lower factual correctness (0.36) and context precision (0.46). This indicates embedding dilution: crucial legal identifiers, such as article numbers and ECLI references, become diluted in the semantic vector space (S & Easwarakumar, 2025).
#
# To improve factual accuracy, a BM25Retriever has been added to the ensemble. Whereas the current vector search focuses on meaning, BM25 enforces precision based on exact keyword matches (lexical matching). This hybrid intervention is necessary to reduce noise in the context and restore the direct link between the query and the specific legal source.
#
# In parallel, Maximum Marginal Relevance (MMR) filtering is introduced to optimize the jurisprudence retrieval channel. Because judicial rulings in Dutch administrative law are inherently narrative and lengthy, standard similarity searches frequently retrieve highly redundant context fragments that reiterate the same legal facts or definitions. This textual redundancy overloads the LLM's limited context window without introducing new information, further driving down context precision and confusing the generator. By implementing MMR, the pipeline actively penalizes redundant text segments and prioritizes information diversity. This ensures that the retrieved context contains a broader, more distinct range of legal perspectives and factual nuances necessary to formulate a comprehensive legal justification.

# %%
# Branch 1: Legislation (PDR + BM25) 
# Fetch documents from vectorstore and handle string conversion safely
leg_data = vdb_leg_child.get()
raw_documents_leg = leg_data.get('documents', []) if leg_data else []

processed_texts_leg = [
    doc.page_content if hasattr(doc, 'page_content') else str(doc) 
    for doc in raw_documents_leg if doc is not None
]

if not processed_texts_leg:
    print("CRITICAL ERROR: 'processed_texts_leg' is empty!")
    print("Please verify that 'vdb_leg_child' is filled and properly initialized.")
    processed_texts_leg = ["Fallback context to prevent zero division error during testing."]

# Initialize sparse keyword retriever for legislation
retriever_leg_bm25 = BM25Retriever.from_texts(processed_texts_leg)
retriever_leg_bm25.k = 5

# Combine retrievers (0.7 dense PDR, 0.3 sparse BM25)
hybrid_leg = EnsembleRetriever(
    retrievers=[retriever_leg_parent, retriever_leg_bm25], 
    weights=[0.7, 0.3]
)

# Branch 2: Jurisprudence (MMR + BM25)
# Configure dense vector retriever to use MMR to reduce redundancy
retriever_juris_mmr = vdb_juris_split.as_retriever(
    search_type="mmr", 
    search_kwargs={"k": 15, "fetch_k": 50, "lambda_mult": 0.5}
)


# Fetch jurisprudence documents in batches
processed_texts_juris = []
batch_limit = 10000
offset = 0

print("Fetching jurisprudence chunks in batches from disk...")
while True:
    juris_batch = vdb_juris_split.get(limit=batch_limit, offset=offset)
    raw_docs_juris_batch = juris_batch.get('documents', []) if 'juri_batch' in locals() else juris_batch.get('documents', [])
    
    if not raw_docs_juris_batch:
        break
        
    for doc in raw_docs_juris_batch:
        if doc is not None:
            processed_texts_juris.append(doc.page_content if hasattr(doc, 'page_content') else str(doc))
            
    print(f"Loaded database batch: chunks collected so far: {len(processed_texts_juris)}")
    
    if len(raw_docs_juris_batch) < batch_limit:
        break
    offset += batch_limit

# Explicit guard for the jurisprudence pipeline
if not processed_texts_juris:
    print("erro: 'processed_texts_juris' is empty!")
    print("Please verify that 'vdb_juris_split' is filled and properly initialized.")
    processed_texts_juris = ["Fallback context to prevent zero division error during testing."]

# Initialize sparse keyword retriever for jurisprudence
retriever_juris_bm25 = BM25Retriever.from_texts(processed_texts_juris)
retriever_juris_bm25.k = 10

# Combine retrievers using an equal 50/50 balance
hybrid_juris = EnsembleRetriever(
    retrievers=[retriever_juris_mmr, retriever_juris_bm25], 
    weights=[0.5, 0.5]
)

# Retriever run 3 (0.6 legislation, 0.4 jurisprudence)
hybrid_ensemble = EnsembleRetriever(
    retrievers=[hybrid_leg, hybrid_juris],
    weights=[0.6, 0.4]
)
# Out:
# Fetching jurisprudence chunks in batches from disk...
# Loaded database batch: chunks collected so far: 10000
# Loaded database batch: chunks collected so far: 20000
# Loaded database batch: chunks collected so far: 30000
# Loaded database batch: chunks collected so far: 40000
# Loaded database batch: chunks collected so far: 50000
# Loaded database batch: chunks collected so far: 51321
# run 6 complete!

# %%
dataset_ensemble = await run_evaluation_loop(ensemble_retriever, qa_list, "hybrid-split-rag-run3")

result_ensemble = await aevaluate(
    dataset=dataset_ensemble,
    metrics=metrics,
    run_config=config
)

print(f"results split RAG ensemble: {result_ensemble}")
# Out:
# Start retrieval and generation for: hybrid-split-rag-run3...
# C:\Users\verkad004\AppData\Local\Temp\ipykernel_26524\1031139407.py:3: DeprecationWarning: aevaluate() is deprecated and will be removed in a future version. Use the @experiment decorator instead. See https://docs.ragas.io/en/latest/concepts/experiment/ for more information.
#   result_ensemble = await aevaluate(
# Evaluating: 100%|██████████| 40/40 [14:09<00:00, 21.24s/it]
# results split RAG ensemble: {'faithfulness': 0.8601, 'factual_correctness(mode=f1)': 0.3320, 'context_precision': 0.5018, 'context_recall': 0.7600}

# %%
# Load split-rag data
df_split = pd.read_csv('../data/results/results_hybrid-split-rag-rerank-2.csv',encoding='utf-16')


# Print split-rag data
for i in range(len(df_split)):
    print(f"Case {i+1}\n")
    print(f"Question:\n{df_split.loc[i, 'question']}\n")
    
    print(f"Answer:\n")
    print(f"{df_split.loc[i, 'answer']}")
    print("-" * 50)
# Out:
# Case 1
#
# Question:
# Kan een omgevingsvergunning voor een dakterras op een gemeentelijk monument worden verleend als het hekwerk de maximale bouwhoogte overschrijdt?
#
# Answer:
#
# Op basis van de verstrekte context kan een omgevingsvergunning voor een dakterras op een gemeentelijk monument niet worden verleend als het hekwerk de maximale bouwhoogte overschrijdt, tenzij er sprake is van een afwijking van het bestemmingsplan die voldoet aan de voorwaarden van de relevante wet- en regelgeving.
#
# ### Wettelijke basis:
# - Artikel 2.12, eerste lid, aanhef en onder a, onder 1˚, van de Wabo (Wet algemene bepalingen omgevingsrecht) biedt de mogelijkheid om af te wijken van het bestemmingsplan, mits dit in overeenstemming is met de planregels en er geen onevenredige aantasting van stedenbouwkundige of cultuurhistorische waarden plaatsvindt.
# - Artikel 25.4.2 van de planregels bepaalt dat afwijkingen alleen mogelijk zijn als de karakteristieke en historische ruimtelijke structuur niet onevenredig worden aangetast.
#
# ### Relevante uitspraak:
# - ECLI:NL:RVS:2024:4057 (uitspraak van 4 september 2024) bevestigt dat een dakterras en hekwerk niet in strijd mogen zijn met de maximale bouwhoogte en dat cultuurhistorische waarden zwaar wegen bij gemeentelijke monumenten.
#
# ### Conclusie:
# Een omgevingsvergunning kan alleen worden verleend als het hekwerk binnen de maximale bouwhoogte blijft of als een afwijking wordt toegestaan die voldoet aan de voorwaarden van artikel 2.12 Wabo en artikel 25.4.2 van de planregels. In de context van een gemeentelijk monument is het onwaarschijnlijk dat een afwijking wordt toegestaan als dit leidt tot aantasting van de cultuurhistorische waarde.
# --------------------------------------------------
# Case 2
#
# Question:
# Is een termijnoverschrijding bij het indienen van een bezwaarschrift tegen een omgevingsvergunning verschoonbaar als het bezwaarschrift tijdig ter post is bezorgd maar door een verkeerde adressering pas na de termijn is ontvangen?
#
# Answer:
#
# Op basis van de verstrekte context is een termijnoverschrijding bij het indienen van een bezwaarschrift tegen een omgevingsvergunning in beginsel niet verschoonbaar, tenzij redelijkerwijs niet kan worden geoordeeld dat de indiener in verzuim is geweest. Dit volgt uit artikel 6:11 van de Algemene wet bestuursrecht (Awb).
#
# In het geval dat een bezwaarschrift tijdig ter post is bezorgd maar door een verkeerde adressering pas na de termijn is ontvangen, kan de verschoonbaarheid afhankelijk zijn van de specifieke omstandigheden. De contextuele benadering vereist dat wordt beoordeeld of de termijnoverschrijding aan de indiener kan worden toegerekend en of het bezwaarschrift zo spoedig mogelijk is ingediend nadat de fout werd ontdekt.
#
# De relevante uitspraak in dit verband is ECLI:NL:RVS:2022:2461, waarin de Afdeling bestuursrechtspraak van de Raad van State oordeelde dat een termijnoverschrijding verschoonbaar kan zijn als de indiener aannemelijk maakt dat het bezwaarschrift tijdig ter post is bezorgd en de vertraging niet aan hem kan worden toegerekend.
#
# Indien aanvullende informatie ontbreekt, kan geen definitief oordeel worden gegeven over de verschoonbaarheid.
# --------------------------------------------------
# Case 3
#
# Question:
# Mag de gemeente een omgevingsvergunning voor funderingsherstel intrekken als de vergunninghouder door financiële geschillen met de buren vier jaar lang niet is begonnen met de werkzaamheden?
#
# Answer:
#
# Op basis van de verstrekte context mag de gemeente een omgevingsvergunning voor funderingsherstel intrekken als de vergunninghouder gedurende vier jaar geen gebruik heeft gemaakt van de vergunning. Dit is in lijn met artikel 5.40, tweede lid, onder d van de **Omgevingswet** (Ow), dat bepaalt dat een omgevingsvergunning kan worden ingetrokken als er gedurende een jaar geen activiteiten zijn verricht met gebruikmaking van de vergunning. Daarnaast is in artikel 2.33, tweede lid, onder a van de **Wet algemene bepalingen omgevingsrecht** (Wabo) bepaald dat een omgevingsvergunning kan worden ingetrokken als er gedurende drie jaar geen gebruik van is gemaakt.
#
# De financiële geschillen met de buren worden in dit geval niet als een rechtvaardiging gezien om af te zien van intrekking, omdat de redenen voor het niet uitvoeren van de werkzaamheden voor risico van de vergunninghouder komen. Dit blijkt ook uit de belangenafweging die in de context is beschreven.
#
# Er is geen specifiek ECLI-nummer genoemd in de context dat direct betrekking heeft op deze situatie.
# --------------------------------------------------
# Case 4
#
# Question:
# Dient de gemeente handhavend op te treden tegen een drijvend terras bij een woonark als de eigenaar stelt dat soortgelijke vlotten van buren tijdens een gemeentelijke nulmeting zijn gedoogd?
#
# Answer:
#
# Op basis van de verstrekte context is de gemeente in beginsel verplicht handhavend op te treden tegen een drijvend terras bij een woonark als sprake is van een overtreding van een wettelijk voorschrift. Dit volgt uit de beginselplicht tot handhaving, zoals bevestigd in vaste rechtspraak. Het algemeen belang dat gediend is met handhaving weegt in de regel zwaarder dan individuele belangen. Alleen onder bijzondere omstandigheden kan van handhaving worden afgezien, bijvoorbeeld als concreet zicht op legalisatie bestaat of als handhaving onevenredig zou zijn.
#
# In dit geval stelt de eigenaar dat soortgelijke vlotten van buren tijdens een gemeentelijke nulmeting zijn gedoogd. Echter, de gemeente heeft aangegeven dat er geen sprake is van gelijke gevallen, omdat de situatie van de buren onder een ander planologisch regime valt. Bovendien heeft de gemeente verklaard dat zij ook tegen overtredingen in andere gevallen zal optreden.
#
# ### Relevante wetsartikelen en rechtspraak:
# 1. **Omgevingswet**: Artikel 2.1, eerste lid, onder a (vergunningplicht voor bouwen).
# 2. **Relevante uitspraak**: ECLI ontbreekt in de verstrekte context.
#
# Indien aanvullende informatie over de ECLI-nummer of specifieke omstandigheden ontbreekt, kan dit niet verder worden gespecificeerd.
# --------------------------------------------------
# Case 5
#
# Question:
# Dient een omgevingsvergunning voor een binnenplanse omgevingsplanactiviteit te worden geweigerd als omwonenden vrezen voor de beschadiging van wortels van een monumentale boom op een naburig perceel?
#
# Answer:
#
# Op basis van de verstrekte context kan worden geconcludeerd dat een omgevingsvergunning voor een binnenplanse omgevingsplanactiviteit geweigerd kan worden als er sprake is van onherstelbare schade aan een monumentale boom of een boom met bijzondere waarden. Dit volgt uit de relevante regelgeving en jurisprudentie.
#
# Volgens artikel **5.1, eerste lid, onder a, van de Omgevingswet** in samenhang met artikel **24.2.3 van de planregels**, mogen werkzaamheden die schade aan wortels, stam of kroon van een boom kunnen veroorzaken, alleen worden toegestaan als er geen onherstelbare schade wordt toegebracht. Het bevoegd gezag kan voorwaarden verbinden aan de vergunning om schade te voorkomen of te beperken.
#
# Daarnaast blijkt uit de context dat het belang van het behoud van de boom expliciet moet worden meegewogen in de besluitvorming. Als dit niet gebeurt, kan dit leiden tot vernietiging van het besluit, zoals ook blijkt uit de overwegingen van de voorzieningenrechter.
#
# Er is echter geen specifiek ECLI-nummer genoemd in de context. Dit ontbreekt expliciet.
# --------------------------------------------------
# Case 6
#
# Question:
# Kan een omgevingsvergunning voor een binnenplanse omgevingsplanactiviteit worden geweigerd omdat het project in strijd zou zijn met het verbod op uitzicht binnen twee meter van de erfgrens?
#
# Answer:
#
# Nee, een omgevingsvergunning voor een binnenplanse omgevingsplanactiviteit kan niet worden geweigerd enkel omdat het project in strijd zou zijn met het verbod op uitzicht binnen twee meter van de erfgrens, tenzij dit expliciet is opgenomen als weigeringsgrond in het omgevingsplan.
#
# Volgens artikel 8.0a, eerste lid, van het Besluit kwaliteit leefomgeving (Bkl) moet een omgevingsvergunning voor een binnenplanse omgevingsplanactiviteit worden verleend als de activiteit niet in strijd is met de regels die in het omgevingsplan zijn gesteld. Het toetsingskader is limitatief-imperatief: als de activiteit voldoet aan de beoordelingsregels in het omgevingsplan, moet de vergunning worden verleend.
#
# In dit geval is het verbod op uitzicht binnen twee meter van de erfgrens geen zelfstandige weigeringsgrond, tenzij dit specifiek in het omgevingsplan is opgenomen. Het college moet dus toetsen aan de regels van het omgevingsplan en de redelijke eisen van welstand, zoals bepaald in artikel 22.29 van het omgevingsplan.
#
# Er is geen ECLI-nummer genoemd in de context, dus een specifieke uitspraak kan niet worden aangehaald.
# --------------------------------------------------
# Case 7
#
# Question:
# Dient een omgevingsvergunning voor het plaatsen van zonnepanelen te worden geweigerd indien een omwonende vreest voor hinderlijke lichtreflectie en visuele verstoring van het stadsgezicht?
#
# Answer:
#
# Op basis van de verstrekte context kan een omgevingsvergunning voor het plaatsen van zonnepanelen worden geweigerd indien het bouwplan in strijd is met de redelijke eisen van ruimtelijke kwaliteit, de cultuurhistorische waarden van een beschermd stadsgezicht aantast, of niet voldoet aan de welstandscriteria. De vrees van een omwonende voor hinderlijke lichtreflectie en visuele verstoring kan echter niet op zichzelf doorslaggevend zijn, tenzij deze vrees voldoende onderbouwd is en de reflectie of verstoring daadwerkelijk leidt tot een onaanvaardbare aantasting van de omgeving.
#
# ### Wettelijke basis:
# - **Artikel 5.16 van de Omgevingswet**: Dit artikel bepaalt dat een omgevingsvergunning kan worden geweigerd als het bouwplan niet voldoet aan de regels voor een goede ruimtelijke ordening, waaronder de bescherming van cultuurhistorische waarden.
#
# ### Relevante uitspraak:
# - **ECLI:NL:RVS:2025:3084**: In deze uitspraak heeft de Afdeling bestuursrechtspraak van de Raad van State geoordeeld dat hinderlijke lichtreflectie geen reden is om een omgevingsvergunning te weigeren, mits de reflectie beperkt blijft door de hoogte, helling en plaatsing van de zonnepanelen en het gebruik van niet-reflecterende materialen.
#
# ### Conclusie:
# Een omgevingsvergunning kan worden geweigerd als de plaatsing van zonnepanelen strijdig is met de cultuurhistorische waarden of de welstandscriteria. De enkele vrees van een omwonende voor hinderlijke lichtreflectie is onvoldoende, tenzij deze vrees goed onderbouwd is en de reflectie daadwerkelijk onaanvaardbare hinder veroorzaakt.
# --------------------------------------------------
# Case 8
#
# Question:
# Blijft het oude recht van toepassing op de invordering van een dwangsom als de last onder dwangsom is opgelegd vóór de inwerkingtreding van de Omgevingswet, maar de overtreding pas daarna is geconstateerd?
#
# Answer:
#
# Ja, het oude recht blijft van toepassing op de invordering van een dwangsom als de last onder dwangsom is opgelegd vóór de inwerkingtreding van de Omgevingswet, ook als de overtreding pas daarna is geconstateerd. Dit volgt uit artikel 4.23, eerste lid, van de Invoeringswet Omgevingswet. Hierin is bepaald dat op een last onder dwangsom en de invordering daarvan het recht van toepassing blijft zoals dat gold onmiddellijk vóór de inwerkingtreding van de Omgevingswet, tot het moment waarop de last volledig is uitgevoerd, de dwangsom volledig is verbeurd en betaald, of de last is opgeheven.
#
# Er is in de verstrekte context echter geen specifiek ECLI-nummer genoemd dat direct betrekking heeft op deze situatie. Als u een specifiek ECLI-nummer nodig heeft, ontbreekt deze informatie in de context.
# --------------------------------------------------
# Case 9
#
# Question:
# Dient een omgevingsvergunning voor een project te worden geweigerd indien een omwonende aantoont dat een alternatief ontwerp van een opbouw tot aanmerkelijk minder schaduwhinder in de tuin zou leiden?
#
# Answer:
#
# Nee, een omgevingsvergunning hoeft niet te worden geweigerd enkel omdat een omwonende aantoont dat een alternatief ontwerp tot aanmerkelijk minder schaduwhinder in de tuin zou leiden. Volgens vaste jurisprudentie van de Afdeling bestuursrechtspraak van de Raad van State moet het college beslissen op de aanvraag zoals die is ingediend. Als het project op zichzelf aanvaardbaar is, kan het bestaan van alternatieven alleen tot weigering van de vergunning leiden als op voorhand duidelijk is dat door verwezenlijking van de alternatieven een gelijkwaardig resultaat kan worden bereikt met aanmerkelijk minder bezwaren. Het is aan degene die zich op een alternatief beroept om dit aannemelijk te maken.
#
# In dit geval is schaduwhinder geen zelfstandige weigeringsgrond onder de Omgevingswet. Het college mag bij de beoordeling van schaduwhinder uitgaan van een vergelijking tussen de toegestane bouwmogelijkheden en de afwijkingen die met de omgevingsvergunning worden toegestaan. Dit volgt uit artikel 2.10, eerste lid, van de Wabo (nu artikel 2.16 van de Omgevingswet).
#
# Relevante uitspraak: ECLI:NL:RVS:2024:1949.
# --------------------------------------------------
# Case 10
#
# Question:
# Kan een belangenvereniging die geen overtreder is toch als belanghebbende worden aangemerkt bij een last onder dwangsom voor herplant, en mag de gemeente bij die last afwijken van de exacte leeftijd of dikte van de oorspronkelijke boom?
#
# Answer:
#
# 1. **Belanghebbendheid van een belangenvereniging**
# Ja, een belangenvereniging kan als belanghebbende worden aangemerkt, ook als zij geen overtreder is. Volgens artikel 1:2, eerste en derde lid, van de Algemene wet bestuursrecht (Awb) is een rechtspersoon belanghebbende als zij krachtens haar statutaire doelstelling en blijkens haar feitelijke werkzaamheden een algemeen of collectief belang behartigt dat rechtstreeks bij het besluit is betrokken. In dit geval kan een bomenstichting belanghebbende zijn als zij zich statutair en feitelijk richt op het behoud van bomen en groen, en het besluit direct invloed heeft op dat belang.
#
# 2. **Afwijken van de exacte leeftijd of dikte van de oorspronkelijke boom**
# De gemeente mag bij een last onder dwangsom voor herplant afwijken van de exacte leeftijd of dikte van de oorspronkelijke boom, mits dit voldoende wordt gemotiveerd. Artikel 5:32a, eerste lid, van de Awb vereist dat de te nemen herstelmaatregelen duidelijk worden omschreven. De gemeente moet daarbij een belangenafweging maken, zoals blijkt uit de jurisprudentie van de Afdeling bestuursrechtspraak van de Raad van State (ABRvS). Het college moet aannemelijk maken dat de herplantplicht in redelijke verhouding staat tot de overtreding en de waarden die de oorspronkelijke boom vertegenwoordigde.
#
# 3. **Relevante wetsartikelen**
# - Artikel 1:2, eerste en derde lid, Awb (belanghebbendheid).
# - Artikel 5:32a, eerste lid, Awb (omschrijving herstelmaatregelen).
#
# 4. **Relevante uitspraak**
# De context bevat geen specifiek ECLI-nummer van een uitspraak die direct betrekking heeft op deze vraag.
#
# Als aanvullende informatie nodig is, kan dit worden aangevuld.
# --------------------------------------------------
